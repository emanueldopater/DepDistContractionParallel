# %%
import os
import subprocess

# %%
nets = ['emails', 'mouse_brain', 'airports']

# %%
net_dir = "results_deepwalk/airports"

for file in os.listdir(net_dir):
    
    if file == '.DS_Store': continue
    
    # if file is not directory, skip
    if not os.path.isdir(net_dir + "/" + file):
        continue

    for emb_file in os.listdir(net_dir +  "/" + file +"/" ):

        # if there is no result folder, create one
        if not os.path.exists(net_dir + "/" + file +"/results_deepwalk"):
            os.makedirs(net_dir + "/" + file + "/results_deepwalk")

        if emb_file in ['.DS_Store', 'results_deepwalk']: continue
        
        # skip
        command = [
            "julia",
            "./CGE_CLI.jl",
            "-g",
            "airports_reindexed.csv",
            "-e",
            os.path.join( net_dir + "/" + file +"/", emb_file),
            "--result_name",
            net_dir + "/" + file +"/results_deepwalk" +  "/" + emb_file + "_result.csv",
            "-v"
        ]
        output = subprocess.check_output(command, shell=False)
# Out:
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.206137
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.212127
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.208214
# ...

# %%
net_dir = "results_deepwalk/emails"

for file in os.listdir(net_dir):
    
    if file == '.DS_Store': continue
    
    # if file is not directory, skip
    if not os.path.isdir(net_dir + "/" + file):
        continue

    for emb_file in os.listdir(net_dir +  "/" + file +"/" ):

        # if there is no result folder, create one
        if not os.path.exists(net_dir + "/" + file +"/results_deepwalk"):
            os.makedirs(net_dir + "/" + file + "/results_deepwalk")

        if emb_file in ['.DS_Store', 'results_deepwalk']: continue
        
        # skip
        command = [
            "julia",
            "./CGE_CLI.jl",
            "-g",
            "emails_reindexed.csv",
            "-e",
            os.path.join( net_dir + "/" + file +"/", emb_file),
            "--result_name",
            net_dir + "/" + file +"/results_deepwalk" +  "/" + emb_file + "_result.csv",
            "-v"
        ]
        output = subprocess.check_output(command, shell=False)
# Out:
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.414911
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.414807
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.413398
# ...

# %%
net_dir = "results_deepwalk/mouse_brain"

for file in os.listdir(net_dir):
    
    if file == '.DS_Store': continue
    
    # if file is not directory, skip
    if not os.path.isdir(net_dir + "/" + file):
        continue

    for emb_file in os.listdir(net_dir +  "/" + file +"/" ):

        # if there is no result folder, create one
        if not os.path.exists(net_dir + "/" + file +"/results_deepwalk"):
            os.makedirs(net_dir + "/" + file + "/results_deepwalk")

        if emb_file in ['.DS_Store', 'results_deepwalk']: continue
        
        # skip
        command = [
            "julia",
            "./CGE_CLI.jl",
            "-g",
            "mouse_brain_reindexed.csv",
            "-e",
            os.path.join( net_dir + "/" + file +"/", emb_file),
            "--result_name",
            net_dir + "/" + file +"/results_deepwalk" +  "/" + emb_file + "_result.csv",
            "-v"
        ]
        output = subprocess.check_output(command, shell=False)
# Out:
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.643565
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.645076
# The latest version of Julia in the `release` channel is 1.10.2+0.aarch64.apple.darwin14. You currently have `1.10.1+0.aarch64.apple.darwin14` installed. Run:
#
#   juliaup update
#
# to install Julia 1.10.2+0.aarch64.apple.darwin14 and update the `release` channel to that version.
# 0.641674
# ...
